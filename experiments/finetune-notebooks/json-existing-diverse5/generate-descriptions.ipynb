# %%
import xml.etree.ElementTree as ET
import pandas as pd
import re
import os


# Function to clean up encoded HTML entities like &lt; &gt;
def clean_html(text):
    replacements = {
        '&lt;': '<',
        '&gt;': '>',
        '&amp;': '&',
    }
    for old, new in replacements.items():
        text = text.replace(old, new)
    return text

def extract_examples(text):
    # Examples are enclosed in <ex> tags </ex>
    # Also, remove the examples from the original text, return both
    examples = re.findall(r'<ex>(.*?)</ex>', text, re.DOTALL)
    text = re.sub(r'<ex>.*?</ex>', '', text, flags=re.DOTALL)
    return text, examples

def remove_tags(text):
    # Remove all tags from the text
    return re.sub(r'<.*?>', '', text)

def remove_defroot(text):
    # Remove def-root open and close tags
    return re.sub(r'<def-root.*?>|</def-root>', '', text)

def remove_extags(text):
    # Remove all <ex> tags from the text
    return re.sub(r'<ex>.*?</ex>', '', text, flags=re.DOTALL)

def replace_t_tags(text, bold=False):
    # Remove all <t> tags from the text
    if bold:
        return re.sub(r'<(?:t|m)>(.*?)</(?:t|m)>', r'**\1**', text)
    return re.sub(r'<(?:t|m)>(.*?)</(?:t|m)>', r'\1', text)

def replace_tags(text):
    # Replace tags of the form: <fex name="Agent"> with <Agent> and replace closing tags from </fex> to </Agent>
    return re.sub(r'<(?:fex|m)\s+name="(.*?)">(.*?)</(?:fex|m)>', r'<\1>\2</\1>', text)

def replace_fen_tags(text):
    # Replace tags of form: <fen>FE</fen> with <FE>FE</FE>
    return re.sub(r'<fen>(.*?)</fen>', r'<\1>\1</\1>', text)

def clean_text(text, remove_tag=False):
    # Strip leading and trailing whitespaces
    # Replace multiple whitespaces with a single space
    clean = re.sub(r'\s+', ' ', remove_tags(text.strip()) if remove_tag else replace_tags(text.strip()))

    return remove_dni(clean)

def remove_dni(text):
    # Remove tags containing DNI
    return re.sub(r'<\w+>DNI<\/\w+>', '', text)
    
    
def replace_tag_abbrev(text, fe_abbr):
    # Replace FE abbreviations with their full names
    for abbr, name in fe_abbr.items():
        text = text.replace(f'<{abbr}>', f'<{name}>').replace(f'</{abbr}>', f'</{name}>')
    return text

def get_annotation_samples(data: pd.DataFrame, frame_name: str, num_samples: int = 5):
    frame_samples = data.query(f'frame == "{frame_name}"')
    frame_samples = frame_samples.drop_duplicates('text').sort_values(by='fe', key=lambda x: x.str.len(), ascending=False)
    
    return frame_samples.head(num_samples)

def add_tags(text, fes):
    sorted_fes = sorted(fes, key=lambda x: x[1])
    
    tagged_str = ''
    prev_end = 0
    for fe in sorted_fes:
        fe_name, start, end = fe
        tagged_str += text[prev_end:start] + f'<{fe_name}>' + text[start:end] + f'</{fe_name}>'
        prev_end = end
    tagged_str += text[prev_end:]
    
    return tagged_str
    

def get_definition(node):
    text, examples = extract_examples(node.text)
    
    text = text.split('\n')[0]

    return remove_defroot(clean_text(text, False)), [clean_text(ex) for ex in examples if ex.strip() != '']


# Function to extract frame information from the XML
def parse_frame(train_data, xml_file):
    # Parse the XML content
    root = ET.parse(xml_file).getroot()

    # Namespace handling
    ns = {'fn': 'http://framenet.icsi.berkeley.edu'}

    # Extract frame name and definition
    frame_name = root.attrib.get('name')
    frame_definition, examples = get_definition(root.find('fn:definition', ns))

    anno_examples = get_annotation_samples(train_data, frame_name, 5)

    tagged_annos = anno_examples.apply(lambda x: add_tags(x['text'], x['fe']), axis=1) if len(anno_examples) > 0 and anno_examples['fe'].iloc[0] else pd.Series()

    examples = examples + tagged_annos.tolist()

    # Extract frame elements
    frame_elements = []
    fe_abbr = {}
    for fe in root.findall('fn:FE', ns):
        fe_name = fe.attrib.get('name')
        fe_definition, fe_examples = get_definition(fe.find('fn:definition', ns))
        
        core_type = fe.attrib.get('coreType')
        
        # Extract frame element abbreviations
        abbr = fe.attrib.get('abbrev')
        if abbr:
            # if abbr in fe_abbr:
            #     assert fe_abbr[abbr] == fe_name, f"Abbreviation {abbr} already exists for {fe_abbr[abbr]} and {fe_name}"
            fe_abbr[fe.attrib.get('abbrev')] = fe_name
            
        frame_elements.append({
            'name': fe_name,
            'definition': remove_tags(fe_definition),
            'examples': [replace_tag_abbrev(replace_t_tags(x, True), fe_abbr) for x in fe_examples],
            'core_type': core_type
        })

    # Return extracted data
    return {
        'frame_name': frame_name.strip(),
        'frame_definition': remove_tags(frame_definition).strip(),
        'examples': examples,
        'frame_elements': frame_elements
    }

# %%
def convert_tags_to_json(example: str, all_fes: set) -> dict:
    # Find all tags and their content in the example
    tags = re.findall(r'<(.*?)>(.*?)</\1>', example)
    dict_tags = dict(tags)
    
    dict_tags.pop('t', None)
    
    return {fe: dict_tags[fe] for fe in dict_tags if fe in all_fes}

def fill_missing_fes(example: dict, all_fes: set) -> dict:
    filled_example = example.copy()
    for fe in all_fes:
        if fe not in filled_example:
            filled_example[fe] = ''
    
    return filled_example

# %%
import pandas as pd
import pickle
import json

# Load training annotations
with open('../../data/raw/os_train.pkl', 'rb') as f:
    train_data = pickle.load(f)

# Parse the frame
frame_dir = '../../data/raw/fndata-1.7/frame/'
frame_strings = []
for frame_file in os.listdir(frame_dir):
# for frame_file in ['Abusing.xml']:
    if not frame_file.endswith('.xml'):
        continue
    
    print(frame_file)
    
    frame_data = parse_frame(train_data, os.path.join(frame_dir, frame_file))

    desc_str = ""
    desc_str += f"Frame Name: {frame_data['frame_name'].strip()}\n"
    desc_str += f"Frame Definition: {frame_data['frame_definition'].strip()}\n"
    
    # desc_str += "Examples:\n"
    # for ex in frame_data['examples']:
    #     if ex.strip():
    #         ex_json = json.dumps(convert_tags_to_json(replace_t_tags(ex.strip()), set([fe['name'] for fe in frame_data['frame_elements']])))
    #         if ex_json and ex_json != '{}':
    #             desc_str += f"  - {remove_tags(ex.strip()).strip()} -> {ex_json}\n"

    desc_str += "\nFrame Elements:\n"
    for fe in frame_data['frame_elements']:
        desc_str += f"{fe['name'].strip()} ({fe['core_type'].strip()}): {fe['definition'].strip()}\n"
        # if fe['examples']:
        #     for ex in fe['examples']:
        #         ex_json = json.dumps(convert_tags_to_json(ex.strip(), set([fe['name'] for fe in frame_data['frame_elements']])))
        #         if ex_json and ex_json != '{}':
        #             desc_str += f"  - {remove_tags(ex.strip()).strip()} -> {ex_json}\n"
        # desc_str += "\n"

    frame_strings.append({'name': frame_data['frame_name'], 'description': desc_str, 'fes': [fe['name'] for fe in frame_data['frame_elements']]})

df = pd.DataFrame(frame_strings)
df.to_csv('frame_descriptions_json.csv', index=False)
# Out:
# Abandonment.xml
# Abounding_with.xml
# Absorb_heat.xml
# Abundance.xml
# Abusing.xml
# Access_scenario.xml
# Accompaniment.xml
# Accomplishment.xml
# Accoutrements.xml
# Accuracy.xml
# Achieving_first.xml
# Active_substance.xml
# Activity.xml
# Activity_abandoned_state.xml
# Activity_done_state.xml
# Activity_finish.xml
# Activity_ongoing.xml
# Activity_pause.xml
# Activity_paused_state.xml
# Activity_prepare.xml
# Activity_ready_state.xml
# Activity_resume.xml
# Activity_start.xml
# Activity_stop.xml
# Actually_occurring_entity.xml
# Addiction.xml
# Adding_up.xml
# Adducing.xml
# Adjacency.xml
# Adjusting.xml
# Adopt_selection.xml
# Aesthetics.xml
# Affirm_or_deny.xml
# Age.xml
# Aggregate.xml
# Aging.xml
# Agree_or_refuse_to_act.xml
# Agriculture.xml
# Aiming.xml
# Alignment_image_schema.xml
# Alliance.xml
# Alternatives.xml
# Alternativity.xml
# Amalgamation.xml
# Amassing.xml
# Ambient_temperature.xml
# Ammunition.xml
# Amounting_to.xml
# Animals.xml
# Annoyance.xml
# Appeal.xml
# Appellations.xml
# Apply_heat.xml
# Appointing.xml
# Architectural_part.xml
# Arithmetic.xml
# Arithmetic_commutative.xml
# Arithmetic_non-commutative.xml
# Armor.xml
# Arraignment.xml
# Arranging.xml
# Arrest.xml
# Arriving.xml
# Arson.xml
# Artifact.xml
# Artifact_subpart.xml
# Artificiality.xml
# Artistic_style.xml
# Assemble.xml
# Assessing.xml
# Assigned_location.xml
# Assistance.xml
# Asymmetric_reciprocality.xml
# Atonement.xml
# Attaching.xml
# Attack.xml
# Attempt.xml
# Attempting_and_resolving_scenario.xml
# Attempt_action_scenario.xml
# Attempt_distant_interaction_scenario.xml
# Attempt_means.xml
# Attempt_obtain_food_scenario.xml
# Attempt_obtain_mineral_scenario.xml
# Attempt_suasion.xml
# Attending.xml
# Attention.xml
# Attention_getting.xml
# Attitude_description.xml
# Attributed_information.xml
# Attributes.xml
# Authority.xml
# Avoiding.xml
# Awareness.xml
# Awareness_situation.xml
# Awareness_status.xml
# Bail_decision.xml
# Basis_for_attribute.xml
# Bearing_arms.xml
# Beat_opponent.xml
# Becoming.xml
# Becoming_attached.xml
# Becoming_aware.xml
# Becoming_a_member.xml
# Becoming_detached.xml
# Becoming_dry.xml
# Becoming_separated.xml
# Becoming_silent.xml
# Becoming_visible.xml
# Behind_the_scenes.xml
# Being_active.xml
# Being_attached.xml
# Being_at_risk.xml
# Being_awake.xml
# Being_born.xml
# Being_contained_within.xml
# Being_detached.xml
# Being_dry.xml
# Being_employed.xml
# Being_incarcerated.xml
# Being_included.xml
# Being_in_captivity.xml
# Being_in_category.xml
# Being_in_control.xml
# Being_in_effect.xml
# Being_in_operation.xml
# Being_located.xml
# Being_named.xml
# Being_necessary.xml
# Being_obligated.xml
# Being_obligatory.xml
# Being_operational.xml
# Being_pregnant.xml
# Being_questionable.xml
# Being_relevant.xml
# Being_rotted.xml
# Being_up_to_it.xml
# Being_wet.xml
# Besieging.xml
# Beyond_compare.xml
# Be_in_agreement_on_action.xml
# Be_in_agreement_on_assessment.xml
# Be_on_alert.xml
# Be_subset_of.xml
# Be_translation_equivalent.xml
# Billing.xml
# Biological_area.xml
# Biological_classification.xml
# Biological_entity.xml
# Biological_mechanisms.xml
# Biological_urge.xml
# Birth_scenario.xml
# Board_vehicle.xml
# Body_decoration.xml
# Body_description_holistic.xml
# Body_description_part.xml
# Body_mark.xml
# Body_movement.xml
# Body_parts.xml
# Bond_maturation.xml
# Borrowing.xml
# Boundary.xml
# Bounded_entity.xml
# Bounded_region.xml
# Bragging.xml
# Breaking_apart.xml
# Breaking_off.xml
# Breaking_out_captive.xml
# Breathing.xml
# Bringing.xml
# Building.xml
# Buildings.xml
# Building_subparts.xml
# Bungling.xml
# Burying.xml
# Businesses.xml
# Business_closure.xml
# Cache.xml
# Calendric_unit.xml
# Candidness.xml
# Capability.xml
# Capacity.xml
# Capital_stock.xml
# Cardinal_numbers.xml
# Carry_goods.xml
# Catastrophe.xml
# Catching_fire.xml
# Categorization.xml
# Causation.xml
# Causation_scenario.xml
# Cause_bodily_experience.xml
# Cause_change.xml
# Cause_change_of_consistency.xml
# Cause_change_of_phase.xml
# Cause_change_of_position_on_a_scale.xml
# Cause_change_of_strength.xml
# Cause_emotion.xml
# Cause_expansion.xml
# Cause_fluidic_motion.xml
# Cause_harm.xml
# Cause_impact.xml
# Cause_motion.xml
# Cause_proliferation_in_number.xml
# Cause_temperature_change.xml
# Cause_to_amalgamate.xml
# Cause_to_be_dry.xml
# Cause_to_be_included.xml
# Cause_to_be_sharp.xml
# Cause_to_be_wet.xml
# Cause_to_burn.xml
# Cause_to_continue.xml
# Cause_to_end.xml
# Cause_to_experience.xml
# Cause_to_fragment.xml
# Cause_to_land.xml
# Cause_to_make_noise.xml
# Cause_to_make_progress.xml
# Cause_to_move_in_place.xml
# Cause_to_perceive.xml
# Cause_to_resume.xml
# Cause_to_rot.xml
# Cause_to_start.xml
# Cause_to_wake.xml
# Ceasing_to_be.xml
# Certainty.xml
# Change_accessibility.xml
# Change_direction.xml
# Change_event_duration.xml
# Change_event_time.xml
# Change_of_consistency.xml
# Change_of_leadership.xml
# Change_of_phase.xml
# Change_of_phase_scenario.xml
# Change_of_quantity_of_possession.xml
# Change_of_temperature.xml
# Change_operational_state.xml
# Change_position_on_a_scale.xml
# Change_post-state.xml
# Change_posture.xml
# Change_resistance.xml
# Change_tool.xml
# Chaos.xml
# Chatting.xml
# Chemical-sense_description.xml
# Chemical_potency.xml
# Choosing.xml
# Circumscribed_existence.xml
# Citing.xml
# Claim_ownership.xml
# Clemency.xml
# Closure.xml
# Clothing.xml
# Clothing_parts.xml
# Co-association.xml
# Cogitation.xml
# Cognitive_connection.xml
# Cognitive_impact.xml
# Coincidence.xml
# Collaboration.xml
# Collocation_image_schema.xml
# Colonization.xml
# Color.xml
# Color_qualities.xml
# Come_down_with.xml
# Come_into_effect.xml
# Come_together.xml
# Coming_to_be.xml
# Coming_to_believe.xml
# Coming_up_with.xml
# Commemorative.xml
# Commerce_buy.xml
# Commerce_collect.xml
# Commerce_goods-transfer.xml
# Commerce_money-transfer.xml
# Commerce_pay.xml
# Commerce_scenario.xml
# Commerce_sell.xml
# Commercial_transaction.xml
# Commitment.xml
# Committing_crime.xml
# Commonality.xml
# Communicate_categorization.xml
# Communication.xml
# Communication_manner.xml
# Communication_means.xml
# Communication_noise.xml
# Communication_response.xml
# Commutation.xml
# Commutative_process.xml
# Commutative_statement.xml
# Compatibility.xml
# Competition.xml
# Complaining.xml
# Completeness.xml
# Compliance.xml
# Concessive.xml
# Conditional_occurrence.xml
# Conditional_scenario.xml
# Condition_symptom_relation.xml
# Conduct.xml
# Conferring_benefit.xml
# Confronting_problem.xml
# Connecting_architecture.xml
# Connectors.xml
# Conquering.xml
# Contacting.xml
# Contact_image_schema.xml
# Containers.xml
# Container_focused_placing.xml
# Container_focused_removing.xml
# Containing.xml
# Containment_scenario.xml
# Contingency.xml
# Continued_state_of_affairs.xml
# Contrary_circumstances.xml
# Contrition.xml
# Control.xml
# Controller_object.xml
# Convey_importance.xml
# Convoy.xml
# Cooking_creation.xml
# Corporal_punishment.xml
# Correctness.xml
# Corroding.xml
# Corroding_caused.xml
# Cotheme.xml
# Counterattack.xml
# Court_examination.xml
# Craft.xml
# Create_physical_artwork.xml
# Create_representation.xml
# Creating.xml
# Crime_scenario.xml
# Criminal_investigation.xml
# Criminal_process.xml
# Cure.xml
# Custom.xml
# Cutting.xml
# Cycle_of_existence_scenario.xml
# Cycle_of_life_and_death.xml
# Damaging.xml
# Daring.xml
# Dead_or_alive.xml
# Death.xml
# Deception_end.xml
# Deception_scenario.xml
# Deception_success.xml
# Deciding.xml
# Defending.xml
# Degree.xml
# Degree_of_processing.xml
# Delimitation_of_diversity.xml
# Delimited_state_scenario.xml
# Delivery.xml
# Deny_or_grant_permission.xml
# Departing.xml
# Deserving.xml
# Desirability.xml
# Desirable_event.xml
# Desiring.xml
# Destiny.xml
# Destroying.xml
# Detaching.xml
# Detaining.xml
# Detonate_explosive.xml
# Differentiation.xml
# Difficulty.xml
# Dimension.xml
# Direction.xml
# Directional_locative_relation.xml
# Disaster_scenario.xml
# Discussion.xml
# Disembarking.xml
# Disgraceful_situation.xml
# Dispersal.xml
# Distant_operated_IED.xml
# Distinctiveness.xml
# Distributed_abundance.xml
# Distributed_position.xml
# Diversity.xml
# Documents.xml
# Dodging.xml
# Domain.xml
# Dominate_competitor.xml
# Dominate_situation.xml
# Domination.xml
# Dough_rising.xml
# Downing.xml
# Dressing.xml
# Drop_in_on.xml
# Dunking.xml
# Duplication.xml
# Duration_description.xml
# Duration_relation.xml
# Duration_scenario.xml
# Dying.xml
# Dynamic_situation_scenario.xml
# Dynamism.xml
# Earnings_and_losses.xml
# Eclipse.xml
# Economy.xml
# Education_teaching.xml
# Electricity.xml
# Elusive_goal.xml
# Emanating.xml
# Emergency.xml
# Emergency_fire.xml
# Emitting.xml
# Emotions.xml
# Emotions_by_possibility.xml
# Emotions_by_stimulus.xml
# Emotions_of_mental_activity.xml
# Emotions_success_or_failure.xml
# Emotion_active.xml
# Emotion_directed.xml
# Emotion_heat.xml
# Emphasizing.xml
# Employee_scenario.xml
# Employer_scenario.xml
# Employing.xml
# Employment_continue.xml
# Employment_end.xml
# Employment_scenario.xml
# Employment_start.xml
# Emptying.xml
# Encoding.xml
# Encounter.xml
# Endangering.xml
# Endeavor_failure.xml
# Enforcing.xml
# Entering_of_plea.xml
# Entity.xml
# Entourage.xml
# Erasing.xml
# Escaping.xml
# Estimated_value.xml
# Estimating.xml
# Evading.xml
# Evaluative_comparison.xml
# Event.xml
# Eventive_affecting.xml
# Eventive_cognizer_affecting.xml
# Event_endstate.xml
# Event_initial_state.xml
# Event_instance.xml
# Evidence.xml
# Evoking.xml
# Examination.xml
# Exchange.xml
# Exchange_currency.xml
# Exclude_member.xml
# Excreting.xml
# Execute_plan.xml
# Execution.xml
# Exemplar.xml
# Exemplariness.xml
# Exercising.xml
# Existence.xml
# Expansion.xml
# Expectation.xml
# Expected_location_of_person.xml
# Expend_resource.xml
# Expensiveness.xml
# Experiencer_focus.xml
# Experiencer_obj.xml
# Experience_bodily_harm.xml
# Experimentation.xml
# Expertise.xml
# Explaining_the_facts.xml
# Explosion.xml
# Exporting.xml
# Expressing_publicly.xml
# Extradition.xml
# Extreme_point.xml
# Extreme_value.xml
# Facial_expression.xml
# Fairness_evaluation.xml
# Fall_asleep.xml
# Fall_for.xml
# Fame.xml
# Familiarity.xml
# Fastener.xml
# Fear.xml
# Feeling.xml
# Feigning.xml
# Fields.xml
# Fighting_activity.xml
# Filling.xml
# Fining.xml
# Finish_competition.xml
# Finish_game.xml
# Firefighting.xml
# Fire_break.xml
# Fire_burning.xml
# Fire_emergency_scenario.xml
# Fire_end_scenario.xml
# Fire_going_out.xml
# Fire_stopping_scenario.xml
# Firing.xml
# Firing_point.xml
# First_experience.xml
# First_rank.xml
# Fleeing.xml
# Fluidic_motion.xml
# Food.xml
# Food_gathering.xml
# Foreign_or_domestic_country.xml
# Forging.xml
# Forgiveness.xml
# Forgoing.xml
# Forming_relationships.xml
# Fragmentation_scenario.xml
# Freeing_from_confinement.xml
# Frequency.xml
# Friction.xml
# Friendly_or_hostile.xml
# Front_for.xml
# Frugality.xml
# Fugitive.xml
# Fullness.xml
# Function.xml
# Funding.xml
# Gathering_up.xml
# Gesture.xml
# Getting.xml
# Getting_scenario.xml
# Getting_triggered.xml
# Getting_underway.xml
# Getting_up.xml
# Getting_vehicle_underway.xml
# Get_a_job.xml
# Give_impression.xml
# Giving.xml
# Giving_birth.xml
# Giving_in.xml
# Giving_scenario.xml
# Gizmo.xml
# Goal.xml
# Going_back_on_a_commitment.xml
# Government_institution.xml
# Go_into_shape.xml
# Gradable_artistic_quality.xml
# Gradable_attributes.xml
# Gradable_proximity.xml
# Graph_shape.xml
# Grasp.xml
# Grinding.xml
# Grooming.xml
# Ground_up.xml
# Growing_food.xml
# Guest_and_host.xml
# Guilt_or_innocence.xml
# Gusto.xml
# Hair_configuration.xml
# Halt.xml
# Have_associated.xml
# Have_as_requirement.xml
# Have_as_translation_equivalent.xml
# Have_visitor_over.xml
# Having_commercial_agreement.xml
# Having_or_lacking_access.xml
# Health_response.xml
# Hearsay.xml
# Heat_potential.xml
# Hedging.xml
# Heralding.xml
# Hiding_objects.xml
# Hindering.xml
# Hiring.xml
# Historic_event.xml
# History.xml
# History_scenario.xml
# Hit_or_miss.xml
# Hit_target.xml
# Holding_off_on.xml
# Hospitality.xml
# Hostile_encounter.xml
# Hunting.xml
# Hunting_scenario.xml
# Hunting_success_or_failure.xml
# Identicality.xml
# Identity.xml
# Identity_scenario.xml
# Idiosyncrasy.xml
# Image_schema.xml
# Imitating.xml
# Immobilization.xml
# Impact.xml
# Importance.xml
# Importing.xml
# Import_export_scenario.xml
# Imposing_obligation.xml
# Impression.xml
# Imprisonment.xml
# Improvement_or_decline.xml
# Improvised_explosive_device.xml
# Inclination.xml
# Inclusion.xml
# Inclusion_scenario.xml
# Increment.xml
# Indicating.xml
# Indigenous_origin.xml
# Individual_history.xml
# Ineffability.xml
# Infecting.xml
# Influencing_potential.xml
# Information.xml
# Information_display.xml
# Infrastructure.xml
# Ingestion.xml
# Ingest_substance.xml
# Ingredients.xml
# Inherent_purpose.xml
# Inhibit_motion_scenario.xml
# Inhibit_movement.xml
# Inspecting.xml
# Installing.xml
# Instance.xml
# Institutionalization.xml
# Institutions.xml
# Intentionally_act.xml
# Intentionally_affect.xml
# Intentionally_create.xml
# Intentional_deception.xml
# Intentional_traversing.xml
# Intercepting.xml
# Interior_profile_relation.xml
# Interrupt_process.xml
# Intoxicants.xml
# Intoxication.xml
# Invading.xml
# Invasion_scenario.xml
# Irregular_combatants.xml
# Isolated_places.xml
# Judgment.xml
# Judgment_communication.xml
# Judgment_direct_address.xml
# Judgment_of_intensity.xml
# Judicial_body.xml
# Jury_deliberation.xml
# Justifying.xml
# Just_found_out.xml
# Key.xml
# Kidnapping.xml
# Killing.xml
# Kinship.xml
# Knot_creation.xml
# Knot_creation_scenario.xml
# Labeling.xml
# Labor_product.xml
# Launch_process.xml
# Law.xml
# Law_enforcement_agency.xml
# Leadership.xml
# Leaving_traces.xml
# Left_to_do.xml
# Legality.xml
# Legal_rulings.xml
# Lending.xml
# Level_of_force_exertion.xml
# Level_of_force_resistance.xml
# Level_of_light.xml
# Light_movement.xml
# Likelihood.xml
# Limitation.xml
# Limiting.xml
# Linguistic_meaning.xml
# Lively_place.xml
# Living_conditions.xml
# Locale.xml
# Locale_by_characteristic_entity.xml
# Locale_by_collocation.xml
# Locale_by_event.xml
# Locale_by_ownership.xml
# Locale_by_use.xml
# Locale_closure.xml
# Locating.xml
# Location_in_time.xml
# Location_of_light.xml
# Location_on_path.xml
# Locative_relation.xml
# Locative_scenario.xml
# Lodging_scenario.xml
# Lose_possession.xml
# Lose_possession_scenario.xml
# Losing.xml
# Losing_it.xml
# Losing_someone.xml
# Losing_track_of.xml
# Losing_track_of_perceiver.xml
# Losing_track_of_theme.xml
# Luck.xml
# Make_acquaintance.xml
# Make_agreement_on_action.xml
# Make_cognitive_connection.xml
# Make_compromise.xml
# Make_noise.xml
# Making_arrangements.xml
# Making_faces.xml
# Manipulate_into_doing.xml
# Manipulate_into_shape.xml
# Manipulation.xml
# Manner.xml
# Manner_of_life.xml
# Manufacturing.xml
# Margin_of_resolution.xml
# Mass_motion.xml
# Mathematical_relationship.xml
# Means.xml
# Measurable_attributes.xml
# Measures.xml
# Measure_area.xml
# Measure_by_action.xml
# Measure_duration.xml
# Measure_linear_extent.xml
# Measure_mass.xml
# Measure_scenario.xml
# Measure_volume.xml
# Medical_conditions.xml
# Medical_instruments.xml
# Medical_interaction_scenario.xml
# Medical_intervention.xml
# Medical_professionals.xml
# Medical_specialties.xml
# Medium.xml
# Meet_specifications.xml
# Meet_with.xml
# Meet_with_response.xml
# Membership.xml
# Member_of_military.xml
# Memorization.xml
# Memory.xml
# Mental_activity.xml
# Mental_property.xml
# Mental_stimulus_exp_focus.xml
# Mental_stimulus_stimulus_focus.xml
# Mention.xml
# Military.xml
# Military_operation.xml
# Mining.xml
# Misdeed.xml
# Money.xml
# Morality_evaluation.xml
# Motion.xml
# Motion_directional.xml
# Motion_noise.xml
# Motion_scenario.xml
# Moving_in_place.xml
# Namesake.xml
# Name_conferral.xml
# Natural_features.xml
# Needing.xml
# Negation.xml
# Negative_conditional.xml
# Network.xml
# Noise_makers.xml
# Non-commutative_process.xml
# Non-commutative_statement.xml
# Non-gradable_proximity.xml
# Noncombatant.xml
# Notability.xml
# Notification_of_charges.xml
# Nuclear_process.xml
# Objective_influence.xml
# Obligation_scenario.xml
# Obscurity.xml
# Obviousness.xml
# Occupy_rank.xml
# Offenses.xml
# Offering.xml
# Offshoot.xml
# Omen.xml
# Ontogeny.xml
# Openness.xml
# Operate_vehicle.xml
# Operate_vehicle_scenario.xml
# Operating_a_system.xml
# Operational_testing.xml
# Opinion.xml
# Opportunity.xml
# Optical_image.xml
# Ordinal_numbers.xml
# Organization.xml
# Origin.xml
# Others_situation_as_stimulus.xml
# Out_of_existence.xml
# Pardon.xml
# Partiality.xml
# Participation.xml
# Partitive.xml
# Part_edge.xml
# Part_inner_outer.xml
# Part_ordered_segments.xml
# Part_orientational.xml
# Part_piece.xml
# Part_whole.xml
# Passing.xml
# Passing_off.xml
# Path_shape.xml
# Path_traveled.xml
# Patrolling.xml
# Pattern.xml
# People.xml
# People_along_political_spectrum.xml
# People_by_age.xml
# People_by_jurisdiction.xml
# People_by_military_specialty.xml
# People_by_morality.xml
# People_by_origin.xml
# People_by_religion.xml
# People_by_residence.xml
# People_by_vocation.xml
# Perception.xml
# Perception_active.xml
# Perception_body.xml
# Perception_experience.xml
# Performers.xml
# Performers_and_roles.xml
# Performing_arts.xml
# Personal_relationship.xml
# Personal_success.xml
# Physical_artworks.xml
# Physical_entity.xml
# Piracy.xml
# Placing.xml
# Placing_scenario.xml
# Planned_trajectory.xml
# Planting.xml
# Plants.xml
# Point_of_dispute.xml
# Political_actions.xml
# Political_locales.xml
# Popularity.xml
# Posing_as.xml
# Position_on_a_scale.xml
# Possession.xml
# Possibility.xml
# Posture.xml
# Post_getting.xml
# Post_giving.xml
# Post_lose_possession.xml
# Post_receiving.xml
# Post_transfer.xml
# Practice.xml
# Praiseworthiness.xml
# Prank.xml
# Precariousness.xml
# Precipitation.xml
# Predicament.xml
# Predicting.xml
# Preference.xml
# Preferred_alternative_scenario.xml
# Preliminaries.xml
# Presence.xml
# Presentation_of_mitigation.xml
# Preserving.xml
# Prevarication.xml
# Preventing_or_letting.xml
# Prevent_or_allow_possession.xml
# Pre_getting.xml
# Pre_giving.xml
# Pre_lose_possession.xml
# Pre_receiving.xml
# Pre_transfer.xml
# Price_per_unit.xml
# Prison.xml
# Probability.xml
# Process.xml
# Processing_materials.xml
# Process_completed_state.xml
# Process_continue.xml
# Process_end.xml
# Process_initial_state.xml
# Process_pause.xml
# Process_resume.xml
# Process_start.xml
# Process_stop.xml
# Process_stopped_state.xml
# Process_uncompleted_state.xml
# Procreative_sex.xml
# Product_delivery.xml
# Product_development.xml
# Product_development_scenario.xml
# Product_line.xml
# Progression.xml
# Prohibiting_or_licensing.xml
# Project.xml
# Proliferating_in_number.xml
# Prominence.xml
# Proper_reference.xml
# Proportion.xml
# Proportional_quantity.xml
# Protecting.xml
# Protest.xml
# Provide_lodging.xml
# Proximity_image_schema.xml
# Public_services.xml
# Publishing.xml
# Punctual_perception.xml
# Purpose.xml
# Putting_out_fire.xml
# Quantified_mass.xml
# Quantity.xml
# Quarreling.xml
# Questioning.xml
# Quitting.xml
# Quitting_a_place.xml
# Race_descriptor.xml
# Range.xml
# Rank.xml
# Ranked_expectation.xml
# Rape.xml
# Rashness.xml
# Rate_description.xml
# Rate_quantification.xml
# Ratification.xml
# Reading_activity.xml
# Reading_aloud.xml
# Reading_perception.xml
# Reason.xml
# Reasoning.xml
# Reassuring.xml
# Rebellion.xml
# Receive_visitor_scenario.xml
# Receiving.xml
# Receiving_scenario.xml
# Reciprocality.xml
# Recording.xml
# Records.xml
# Recovery.xml
# Redirecting.xml
# Reference_text.xml
# Referring_by_name.xml
# Reforming_a_system.xml
# Regard.xml
# Region_with_portal.xml
# Rejuvenation.xml
# Relating_concepts.xml
# Relation.xml
# Relational_location.xml
# Relational_natural_features.xml
# Relational_political_locales.xml
# Relational_quantity.xml
# Relation_between_individuals.xml
# Relative_time.xml
# Releasing.xml
# Releasing_from_custody.xml
# Reliance.xml
# Reliance_on_expectation.xml
# Religious_belief.xml
# Remainder.xml
# Remembering_experience.xml
# Remembering_information.xml
# Remembering_to_do.xml
# Removing.xml
# Removing_scenario.xml
# Render_nonfunctional.xml
# Renting.xml
# Renting_out.xml
# Renunciation.xml
# Reparation.xml
# Repayment.xml
# Repel.xml
# Replacing.xml
# Reporting.xml
# Representative.xml
# Representing.xml
# Request.xml
# Request_entity.xml
# Required_event.xml
# Requirement_scenario.xml
# Rescuing.xml
# Research.xml
# Reserving.xml
# Reshaping.xml
# Residence.xml
# Resolve_problem.xml
# Respond_to_proposal.xml
# Response.xml
# Response_scenario.xml
# Responsibility.xml
# Rest.xml
# Result_of_attempt_scenario.xml
# Resurrection.xml
# Retaining.xml
# Reveal_secret.xml
# Revenge.xml
# Revolution.xml
# Rewards_and_punishments.xml
# Ride_vehicle.xml
# Rising_to_a_challenge.xml
# Risky_situation.xml
# Risk_scenario.xml
# Rite.xml
# Roadways.xml
# Robbery.xml
# Rope_manipulation.xml
# Rotting.xml
# Run_risk.xml
# Sacrificing_for.xml
# Satisfying.xml
# Scarcity.xml
# Scheduling.xml
# Scope.xml
# Scouring.xml
# Scrutinizing_for.xml
# Scrutiny.xml
# Searching_scenario.xml
# Secrecy_status.xml
# Seeking.xml
# Seeking_to_achieve.xml
# See_through.xml
# Self_control.xml
# Self_motion.xml
# Sending.xml
# Sensation.xml
# Sentencing.xml
# Sent_items.xml
# Separating.xml
# Sequence.xml
# Serving_in_capacity.xml
# Setting_back_burn.xml
# Setting_fire.xml
# Setting_out.xml
# Set_of_interrelated_entities.xml
# Set_relation.xml
# Severity_of_offense.xml
# Sex.xml
# Sexual_reproduction_scenario.xml
# Shaped_part.xml
# Shapes.xml
# Sharing.xml
# Sharpness.xml
# Shooting_scenario.xml
# Shoot_projectiles.xml
# Shopping.xml
# Short_selling.xml
# Sidereal_appearance.xml
# Sign.xml
# Sign_agreement.xml
# Silencing.xml
# Similarity.xml
# Simple_name.xml
# Simple_naming.xml
# Simultaneity.xml
# Size.xml
# Sleep.xml
# Sleep_wake_cycle.xml
# Smuggling.xml
# Soaking.xml
# Soaking_up.xml
# Sociability.xml
# Socially_significant_history_scenario.xml
# Social_behavior_evaluation.xml
# Social_connection.xml
# Social_desirability.xml
# Social_event.xml
# Social_event_collective.xml
# Social_event_individuals.xml
# Social_interaction_evaluation.xml
# Sole_instance.xml
# Sounds.xml
# Sound_level.xml
# Sound_movement.xml
# Source_of_getting.xml
# Source_path_goal.xml
# Spatial_co-location.xml
# Spatial_contact.xml
# Speak_on_topic.xml
# Specific_individual.xml
# Speed_description.xml
# Spelling_and_pronouncing.xml
# Sports_jargon.xml
# Stage_of_progress.xml
# Standing_by.xml
# State.xml
# Statement.xml
# State_continue.xml
# State_of_entity.xml
# Stimulus_focus.xml
# Stinginess.xml
# Store.xml
# Storing.xml
# Strictness.xml
# Studying.xml
# Suasion.xml
# Subjective_influence.xml
# Subjective_temperature.xml
# Submitting_documents.xml
# Subordinates_and_superiors.xml
# Subsisting.xml
# Substance.xml
# Substance_by_phase.xml
# Subversion.xml
# Successfully_communicate_message.xml
# Successful_action.xml
# Success_or_failure.xml
# Sufficiency.xml
# Suicide_attack.xml
# Suitability.xml
# Summarizing.xml
# Supply.xml
# Supporting.xml
# Surpassing.xml
# Surrendering.xml
# Surrendering_possession.xml
# Surrounding.xml
# Surviving.xml
# Suspicion.xml
# Symmetrical_collective_reciprocality.xml
# System.xml
# System_complexity.xml
# Take_place_of.xml
# Taking.xml
# Taking_captive.xml
# Taking_sides.xml
# Taking_time.xml
# Talking_into.xml
# Tasting.xml
# Team.xml
# Telling.xml
# Temperature.xml
# Temporal_collocation.xml
# Temporal_pattern.xml
# Temporal_subregion.xml
# Temporary_group.xml
# Temporary_leave.xml
# Temporary_stay.xml
# Temporary_transfer_scenario.xml
# Terms_of_agreement.xml
# Terrorism.xml
# Text.xml
# Text_creation.xml
# Theft.xml
# Thermodynamic_phase.xml
# Thriving.xml
# Thwarting.xml
# Timespan.xml
# Timetable.xml
# Time_period_of_action.xml
# Time_vector.xml
# Tolerating.xml
# Tool_purpose.xml
# Topic.xml
# Touring.xml
# Toxic_substance.xml
# Transfer.xml
# Transfer_scenario.xml
# Transition_to_a_quality.xml
# Transition_to_a_situation.xml
# Transition_to_state.xml
# Transitive_action.xml
# Translating.xml
# Transportation_status.xml
# Trap.xml
# Travel.xml
# Traversing.xml
# Treating_and_mistreating.xml
# Trendiness.xml
# Trial.xml
# Triggering.xml
# Trust.xml
# Trying_out.xml
# Try_defendant.xml
# Turning_out.xml
# Type.xml
# Typicality.xml
# Unattributed_information.xml
# Undergoing.xml
# Undergoing_scenario.xml
# Undergo_change.xml
# Undergo_transformation.xml
# Undressing.xml
# Unemployment_rate.xml
# Used_up.xml
# Usefulness.xml
# Use_firearm.xml
# Use_vehicle.xml
# Using.xml
# Using_resource.xml
# Vehicle.xml
# Vehicle_departure_initial_stage.xml
# Vehicle_landing.xml
# Vehicle_subpart.xml
# Verdict.xml
# Verification.xml
# Version_sequence.xml
# Victim_operated_IED.xml
# Violence.xml
# Visiting.xml
# Visiting_scenario.xml
# Visiting_scenario_arrival.xml
# Visiting_scenario_departing.xml
# Visiting_scenario_stay.xml
# Visitor_and_host.xml
# Visitor_arrival.xml
# Visitor_departure.xml
# Visitor_scenario.xml
# Visit_host.xml
# Visit_host_arrival.xml
# Visit_host_departure.xml
# Visit_host_stay.xml
# Vocalizations.xml
# Volubility.xml
# Wagering.xml
# Waiting.xml
# Waking_up.xml
# Want_suspect.xml
# Warning.xml
# Waver_between_options.xml
# Wealthiness.xml
# Weapon.xml
# Wearing.xml
# Weather.xml
# Wholes_and_parts.xml
# Willingness.xml
# Win_prize.xml
# Withdraw_from_participation.xml
# Within_distance.xml
# Word_relations.xml
# Work.xml
# Working_a_post.xml
